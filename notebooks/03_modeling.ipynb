# %%
import importlib.util
import subprocess
import sys

missing = [pkg for pkg in ['xgboost', 'shap'] if importlib.util.find_spec(pkg) is None]
if missing:
    print('Installing missing dependencies:', ', '.join(missing))
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', *missing])
    print('Installation complete. Restart the kernel and rerun from the top.')
else:
    print('All required dependencies are already installed.')
# Out:
# All required dependencies are already installed.

# %%
# --- Cell 1: Environment Preparation and Ingestion ---
import sys
import os
import pandas as pd

# Direct notebook to find internal modules
sys.path.append(os.path.abspath(os.path.join('..')))
from src.data_loader import InsuranceDataLoader
from src.modeling import InsurancePredictiveModeler

# Ingest your baseline data asset
loader = InsuranceDataLoader(file_path="../data/MachineLearningRating_v3.txt")
df = loader.load_and_initialize()
print(f"Dataset successfully staged. Total Rows: {len(df):,}")
# Out:
# Dataset successfully staged. Total Rows: 1,000,098

# %%
# --- Cell 2: Multi-Model Evaluation Matrix ---
modeler = InsurancePredictiveModeler(df)
X, y = modeler.prepare_features_and_targets(target_col='TotalClaims')

# Run multi-model benchmarking evaluation pipeline
performance_metrics = modeler.evaluate_all_models(X, y)
print("\n📊 10 ACADEMY PERFORMANCE COMPARISON GRAPH:")
performance_metrics
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 6
#       2 modeler = InsurancePredictiveModeler(df)
#       3 X, y = modeler.prepare_features_and_targets(target_col='TotalClaims')
#       4
#       5 # Run multi-model benchmarking evaluation pipeline
# ----> 6 performance_metrics = modeler.evaluate_all_models(X, y)
#       7 print("\n📊 10 ACADEMY PERFORMANCE COMPARISON GRAPH:")
#       8 performance_metrics
#
# File c:\Users\Guyatu\insurance-risk-analytics\src\modeling.py:45, in InsurancePredictiveModeler.evaluate_all_models(self, X, y)
#      42 results = []
#      44 for name, model in self.models.items():
# ---> 45     model.fit(X_train, y_train)
#      46     preds = model.predict(X_test)
#      47     rmse = np.sqrt(mean_squared_error(y_test, preds))
#
# ...
